# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
limit_rows   = 7000000
train           = pd.read_csv("train_ver2.csv",dtype={"sexo":str,
                                                    "ind_nuevo":str,
                                                    "ult_fec_cli_1t":str,
                                                    "indext":str}, nrows=limit_rows)
# Out:
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/3775245202.py:2: DtypeWarning: Columns (5,8,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   train           = pd.read_csv("train_ver2.csv",dtype={"sexo":str,

# %%
train.columns
# Out:
# Index(['fecha_dato', 'ncodpers', 'ind_empleado', 'pais_residencia', 'sexo',
#        'age', 'fecha_alta', 'ind_nuevo', 'antiguedad', 'indrel',
#        'ult_fec_cli_1t', 'indrel_1mes', 'tiprel_1mes', 'indresi', 'indext',
#        'conyuemp', 'canal_entrada', 'indfall', 'tipodom', 'cod_prov',
#        'nomprov', 'ind_actividad_cliente', 'renta', 'segmento',
#        'ind_ahor_fin_ult1', 'ind_aval_fin_ult1', 'ind_cco_fin_ult1',
#        'ind_cder_fin_ult1', 'ind_cno_fin_ult1', 'ind_ctju_fin_ult1',
#        'ind_ctma_fin_ult1', 'ind_ctop_fin_ult1', 'ind_ctpp_fin_ult1',
#        'ind_deco_fin_ult1', 'ind_deme_fin_ult1', 'ind_dela_fin_ult1',
#        'ind_ecue_fin_ult1', 'ind_fond_fin_ult1', 'ind_hip_fin_ult1',
#        'ind_plan_fin_ult1', 'ind_pres_fin_ult1', 'ind_reca_fin_ult1',
#        'ind_tjcr_fin_ult1', 'ind_valo_fin_ult1', 'ind_viv_fin_ult1',
#        'ind_nomina_ult1', 'ind_nom_pens_ult1', 'ind_recibo_ult1'],
#       dtype='object')

# %%
train.columns = ['Status_Dt', 'Cust_ID', 'Emp_Status', 'Cust_Ctry', 'Cust_Sex', 'Age', 'Join_Dt',
                'Is_New_Cust', 'Cust_Since', 'Relship_Status','Lst_Dt_Primary_Cust', 'Cust_Type_Mth_Beg', 
                'Cust_Relship_Type_Mth_Beg', 'Residence_Ctry', 'Is_Foreigner', 'Is_Spouse_Emp', 'Join_Channel', 'Deceased_Flg', 
                'Address_Type', 'Cust_Province_Cd', 'Cust_Province_Name', 'Cust_Active_Status', 'Gross_HHLD_Income',
                'Cust_Segment', 'Savings_Acct', 'Guarantees', 'Cur_Acct', 'Derivative_Acct', 'Payroll_Acct',
                'Junior_Acct', 'Mas_Particular_Acct', 'Particular_Acct', 'Particular_Plus_Acct', 'Short_Term_Deposits',
                'Med_Term_Deposits', 'Long_Term_Deposits', 'e-Acct', 'Funds', 'Mortgage', 'Pension1', 'Loans',
                'Taxes', 'Credit_Card', 'Securities', 'Home_Acct', 'Payroll', 'Pension2', 'Direct_Debit']

# %%
train.describe()
# Out:
#             Cust_ID      Cust_Sex           Age    Cust_Since  Relship_Status  \
# count  6.843001e+06  6.843001e+06  6.843001e+06  6.843001e+06    6.843001e+06
# mean   8.002765e+05  5.474322e-01  4.031920e+01  7.800718e+01    1.127201e+00
# std    4.184463e+05  4.977451e-01  1.712016e+01  1.711008e+03    3.528387e+00
# min    1.588900e+04  0.000000e+00  2.000000e+00 -9.999990e+05    1.000000e+00
# 25%    4.185780e+05  0.000000e+00  2.400000e+01  2.300000e+01    1.000000e+00
# 50%    9.199900e+05  1.000000e+00  3.900000e+01  4.800000e+01    1.000000e+00
# 75%    1.162457e+06  1.000000e+00  5.100000e+01  1.400000e+02    1.000000e+00
# max    1.465865e+06  1.000000e+00  1.630000e+02  2.490000e+02    9.900000e+01
#
#        Join_Channel  Address_Type  Cust_Province_Cd  Cust_Active_Status  \
# count  6.843001e+06     6843001.0      6.843001e+06        6.843001e+06
# mean   1.008845e+02           1.0      2.557645e+01        4.922931e-01
# std    5.530531e+01           0.0      1.273390e+01        4.999406e-01
# min    0.000000e+00           1.0      0.000000e+00        0.000000e+00
# 25%    2.400000e+01           1.0      1.400000e+01        0.000000e+00
# 50%    1.220000e+02           1.0      2.700000e+01        0.000000e+00
# 75%    1.500000e+02           1.0      3.300000e+01        1.000000e+00
# max    1.590000e+02           1.0      5.100000e+01        1.000000e+00
#
#        Gross_HHLD_Income  ...         Funds      Mortgage      Pension1  \
# count       6.843001e+06  ...  6.843001e+06  6.843001e+06  6.843001e+06
# mean        1.289443e+05  ...  2.089653e-02  6.861171e-03  1.052126e-02
# std         2.100449e+05  ...  1.430380e-01  8.254754e-02  1.020322e-01
# min         1.202730e+03  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         7.481280e+04  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 50%         1.019684e+05  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 75%         1.416312e+05  ...  0.000000e+00  0.000000e+00  0.000000e+00
# max         2.889440e+07  ...  1.000000e+00  1.000000e+00  1.000000e+00
#
#               Loans         Taxes   Credit_Card    Securities     Home_Acct  \
# count  6.843001e+06  6.843001e+06  6.843001e+06  6.843001e+06  6.843001e+06
# mean   2.789566e-03  5.594592e-02  5.085152e-02  2.821861e-02  4.479906e-03
# std    5.274262e-02  2.298173e-01  2.196944e-01  1.655969e-01  6.678201e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#             Payroll  Direct_Debit
# count  6.843001e+06  6.843001e+06
# mean   6.061434e-02  1.393055e-01
# std    2.386216e-01  3.462651e-01
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00
#
# [8 rows x 34 columns]

# %% [markdown]
# ## Correlation Matrix -

# %%
corr_matrix = train.corr()
fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2094054173.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = train.corr()

# %%
train = train.drop(['Pension2'], axis = 1)

# %% [markdown]
# ## Convert DataTypes

# %%
train["Age"]   = pd.to_numeric(train["Age"], errors="coerce")
train["Cust_Since"]   = pd.to_numeric(train["Cust_Since"], errors="coerce")
train["Gross_HHLD_Income"]   = pd.to_numeric(train["Gross_HHLD_Income"], errors="coerce")

# %% [markdown]
# ## Checking for Missing Values

# %%
train.isnull().mean() * 100
# Out:
# Status_Dt                     0.000000
# Cust_ID                       0.000000
# Emp_Status                    0.396200
# Cust_Ctry                     0.396200
# Cust_Sex                      0.396686
# Age                           0.396200
# Join_Dt                       0.396200
# Is_New_Cust                   0.396200
# Cust_Since                    0.396200
# Relship_Status                0.396200
# Lst_Dt_Primary_Cust          99.843557
# Cust_Type_Mth_Beg             1.497200
# Cust_Relship_Type_Mth_Beg     1.497200
# Residence_Ctry                0.396200
# Is_Foreigner                  0.396200
# Is_Spouse_Emp                99.985743
# Join_Channel                  1.703600
# Deceased_Flg                  0.396200
# Address_Type                  0.396200
# Cust_Province_Cd              0.915571
# Cust_Province_Name            0.915571
# Cust_Active_Status            0.396200
# Gross_HHLD_Income            17.889371
# Cust_Segment                  1.718914
# Savings_Acct                  0.000000
# Guarantees                    0.000000
# Cur_Acct                      0.000000
# Derivative_Acct               0.000000
# Payroll_Acct                  0.000000
# Junior_Acct                   0.000000
# Mas_Particular_Acct           0.000000
# Particular_Acct               0.000000
# Particular_Plus_Acct          0.000000
# Short_Term_Deposits           0.000000
# Med_Term_Deposits             0.000000
# Long_Term_Deposits            0.000000
# e-Acct                        0.000000
# Funds                         0.000000
# Mortgage                      0.000000
# Pension1                      0.000000
# Loans                         0.000000
# Taxes                         0.000000
# Credit_Card                   0.000000
# Securities                    0.000000
# Home_Acct                     0.000000
# Payroll                       0.229471
# Direct_Debit                  0.000000
# dtype: float64

# %%
train['Is_New_Cust'] = train['Is_New_Cust'].fillna(1)

median = train['Gross_HHLD_Income'].median()
train['Gross_HHLD_Income'] = train['Gross_HHLD_Income'].fillna(median)

#99%
train.drop(columns=['Lst_Dt_Primary_Cust','Is_Spouse_Emp'], inplace=True)
train.drop(columns=['Cust_Ctry'], inplace=True)

train['Payroll'] = train['Payroll'].fillna(0)

#A is the most frequent category


train = train.dropna(subset = ['Cust_Type_Mth_Beg', 'Cust_Relship_Type_Mth_Beg' , 'Cust_Province_Name', 'Cust_Province_Cd', 'Join_Channel', 'Cust_Segment', 'Cust_Sex'])

# %%
train.isnull().mean() * 100
# Out:
# Status_Dt                    0.0
# Cust_ID                      0.0
# Emp_Status                   0.0
# Cust_Sex                     0.0
# Age                          0.0
# Join_Dt                      0.0
# Is_New_Cust                  0.0
# Cust_Since                   0.0
# Relship_Status               0.0
# Cust_Type_Mth_Beg            0.0
# Cust_Relship_Type_Mth_Beg    0.0
# Residence_Ctry               0.0
# Is_Foreigner                 0.0
# Join_Channel                 0.0
# Deceased_Flg                 0.0
# Address_Type                 0.0
# Cust_Province_Cd             0.0
# Cust_Province_Name           0.0
# Cust_Active_Status           0.0
# Gross_HHLD_Income            0.0
# Cust_Segment                 0.0
# Savings_Acct                 0.0
# Guarantees                   0.0
# Cur_Acct                     0.0
# Derivative_Acct              0.0
# Payroll_Acct                 0.0
# Junior_Acct                  0.0
# Mas_Particular_Acct          0.0
# Particular_Acct              0.0
# Particular_Plus_Acct         0.0
# Short_Term_Deposits          0.0
# Med_Term_Deposits            0.0
# Long_Term_Deposits           0.0
# e-Acct                       0.0
# Funds                        0.0
# Mortgage                     0.0
# Pension1                     0.0
# Loans                        0.0
# Taxes                        0.0
# Credit_Card                  0.0
# Securities                   0.0
# Home_Acct                    0.0
# Payroll                      0.0
# Direct_Debit                 0.0
# dtype: float64

# %% [markdown]
# ### Cateogorical Encoding of Variables

# %%
#Categorical Encoding:
le = LabelEncoder()
train_mask = ~train['Cust_Sex'].isnull()
train.loc[train_mask, 'Cust_Sex'] = le.fit_transform(train['Cust_Sex'][train_mask])

le = LabelEncoder()
train_mask = ~train['Join_Channel'].isnull()
train.loc[train_mask, 'Join_Channel'] = le.fit_transform(train['Join_Channel'][train_mask])

le = LabelEncoder()
train_mask = ~train['Cust_Segment'].isnull()
train.loc[train_mask, 'Cust_Segment'] = le.fit_transform(train['Cust_Segment'][train_mask])

le = LabelEncoder()
train_mask = ~train['Cust_Province_Cd'].isnull()
train.loc[train_mask, 'Cust_Province_Cd'] = le.fit_transform(train['Cust_Province_Cd'][train_mask])

#print(train.dtypes)
['Join_Channel','Cust_Province_Cd','Cust_Segment']
# Out:
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2506736288.py:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   train.loc[train_mask, 'Cust_Sex'] = le.fit_transform(train['Cust_Sex'][train_mask])
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2506736288.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   train.loc[train_mask, 'Join_Channel'] = le.fit_transform(train['Join_Channel'][train_mask])
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2506736288.py:12: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   train.loc[train_mask, 'Cust_Segment'] = le.fit_transform(train['Cust_Segment'][train_mask])
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2506736288.py:16: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   train.loc[train_mask, 'Cust_Province_Cd'] = le.fit_transform(train['Cust_Province_Cd'][train_mask])
# ['Join_Channel', 'Cust_Province_Cd', 'Cust_Segment']

# %% [markdown]
# ## Graphs and distribution

# %% [markdown]
# ### Visualising the distribution of each product by age by boxplot¶

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8,4))

sns.distplot(train.Age[(train.Age>=0) & (train.Age<=130)], kde=False, ax=axes, axlabel='train age')
# Out:
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/1837621259.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train.Age[(train.Age>=0) & (train.Age<=130)], kde=False, ax=axes, axlabel='train age')
# <AxesSubplot: xlabel='train age'>

# %%
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(8,14))
plt.subplots_adjust(wspace=1.3, hspace=0.6)
fig_row=0
for col_id in range(22, 44):
    ax_id=col_id-22
    fig_label=train.columns[col_id]
    feat=train.columns[col_id]
    fig_col=(col_id-1)%5
    box_plot=sns.boxplot(y='Age', data=train[(train[feat]==1) &
    (train['Age']>0) & (train['Age']<100)], ax=axes[fig_row][fig_col])
    box_plot.set(xlabel=fig_label)
    if fig_col==4: fig_row+=1

# %% [markdown]
# ### Distribution of product by Cod_prov¶

# %%
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(8,14))
plt.subplots_adjust(wspace=1.3, hspace=0.6)
fig_row=0
for col_id in range(22, 44):
    ax_id=col_id-22
    fig_label=train.columns[col_id]
    feat=train.columns[col_id]
    fig_col=(col_id-1)%5
    box_plot=sns.boxplot(y='Age', data=train[(train[feat]==1) & 
                                             (train['Age']>0) & (train['Age']<100)], ax=axes[fig_row][fig_col])
    box_plot.set(xlabel=fig_label)
    if fig_col==4: fig_row+=1

# %% [markdown]
# ### Distribution of product among different genders¶

# %%
fig, axes = plt.subplots(nrows=6, ncols=4, figsize=(8,14))
plt.subplots_adjust(wspace=0.8, hspace=0.5)
# fig.tight_layout()
fig_row=0
for col_id in range(22, 44):
    ax_id=col_id-22
    fig_label= train.columns[col_id]
    feat=train.columns[col_id]
    fig_col=(col_id-1)%4
    countplot=sns.countplot(x='Cust_Sex', data=train[(train[feat]==1) & (train['Cust_Sex']>=0)],ax=axes[fig_row][fig_col])
    countplot.set(xlabel=fig_label)
    if fig_col==3: fig_row+=1

# %% [markdown]
# ### Transform Test Data

# %%
limit_rows   = 7000000

test = pd.read_csv("train_ver2.csv",dtype={"sexo":str,
                                             "ind_nuevo":str,
                                               "ult_fec_cli_1t":str,
                                                "indext":str}, nrows=limit_rows)
# Out:
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/316285499.py:3: DtypeWarning: Columns (5,8,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv("train_ver2.csv",dtype={"sexo":str,

# %%
test.columns = ['Status_Dt', 'Cust_ID', 'Emp_Status', 'Cust_Ctry', 'Cust_Sex', 'Age', 'Join_Dt',
                'Is_New_Cust', 'Cust_Since', 'Relship_Status','Lst_Dt_Primary_Cust', 'Cust_Type_Mth_Beg', 
                'Cust_Relship_Type_Mth_Beg', 'Residence_Ctry', 'Is_Foreigner', 'Is_Spouse_Emp', 'Join_Channel', 'Deceased_Flg', 
                'Address_Type', 'Cust_Province_Cd', 'Cust_Province_Name', 'Cust_Active_Status', 'Gross_HHLD_Income',
                'Cust_Segment', 'Savings_Acct', 'Guarantees', 'Cur_Acct', 'Derivative_Acct', 'Payroll_Acct',
                'Junior_Acct', 'Mas_Particular_Acct', 'Particular_Acct', 'Particular_Plus_Acct', 'Short_Term_Deposits',
                'Med_Term_Deposits', 'Long_Term_Deposits', 'e-Acct', 'Funds', 'Mortgage', 'Pension1', 'Loans',
                'Taxes', 'Credit_Card', 'Securities', 'Home_Acct', 'Payroll', 'Pension2', 'Direct_Debit']

# %%
test = test.drop(['Pension2'], axis = 1)

# %%
test["Age"] = pd.to_numeric(test["Age"], errors="coerce")
test["Cust_Since"] = pd.to_numeric(test["Cust_Since"], errors="coerce")
test["Gross_HHLD_Income"] = pd.to_numeric(test["Gross_HHLD_Income"], errors="coerce")

# %%
test['Is_New_Cust'] = test['Is_New_Cust'].fillna(1)

median = test['Gross_HHLD_Income'].median()
test['Gross_HHLD_Income'] = test['Gross_HHLD_Income'].fillna(median)

#99%
test.drop(columns=['Lst_Dt_Primary_Cust','Is_Spouse_Emp'], inplace=True)
test.drop(columns=['Cust_Ctry'], inplace=True)

test['Payroll'] = test['Payroll'].fillna(0)

#A is the most frequent category

test = test.dropna(subset = ['Cust_Type_Mth_Beg', 'Cust_Relship_Type_Mth_Beg' , 'Cust_Province_Name', 'Cust_Province_Cd', 'Join_Channel', 'Cust_Segment', 'Cust_Sex'])

# %%
test.isnull().mean() * 100
# Out:
# Status_Dt                    0.0
# Cust_ID                      0.0
# Emp_Status                   0.0
# Cust_Sex                     0.0
# Age                          0.0
# Join_Dt                      0.0
# Is_New_Cust                  0.0
# Cust_Since                   0.0
# Relship_Status               0.0
# Cust_Type_Mth_Beg            0.0
# Cust_Relship_Type_Mth_Beg    0.0
# Residence_Ctry               0.0
# Is_Foreigner                 0.0
# Join_Channel                 0.0
# Deceased_Flg                 0.0
# Address_Type                 0.0
# Cust_Province_Cd             0.0
# Cust_Province_Name           0.0
# Cust_Active_Status           0.0
# Gross_HHLD_Income            0.0
# Cust_Segment                 0.0
# Savings_Acct                 0.0
# Guarantees                   0.0
# Cur_Acct                     0.0
# Derivative_Acct              0.0
# Payroll_Acct                 0.0
# Junior_Acct                  0.0
# Mas_Particular_Acct          0.0
# Particular_Acct              0.0
# Particular_Plus_Acct         0.0
# Short_Term_Deposits          0.0
# Med_Term_Deposits            0.0
# Long_Term_Deposits           0.0
# e-Acct                       0.0
# Funds                        0.0
# Mortgage                     0.0
# Pension1                     0.0
# Loans                        0.0
# Taxes                        0.0
# Credit_Card                  0.0
# Securities                   0.0
# Home_Acct                    0.0
# Payroll                      0.0
# Direct_Debit                 0.0
# dtype: float64

# %%
le = LabelEncoder()
test_mask = ~test['Cust_Sex'].isnull()
test.loc[test_mask, 'Cust_Sex'] = le.fit_transform(test['Cust_Sex'][test_mask])

le = LabelEncoder()
test_mask = ~test['Join_Channel'].isnull()
test.loc[test_mask, 'Join_Channel'] = le.fit_transform(test['Join_Channel'][test_mask])

le = LabelEncoder()
test_mask = ~test['Cust_Segment'].isnull()
test.loc[test_mask, 'Cust_Segment'] = le.fit_transform(test['Cust_Segment'][test_mask])

le = LabelEncoder()
test_mask = ~test['Cust_Province_Cd'].isnull()
test.loc[test_mask, 'Cust_Province_Cd'] = le.fit_transform(test['Cust_Province_Cd'][test_mask])
# Out:
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2338881131.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   test.loc[test_mask, 'Cust_Sex'] = le.fit_transform(test['Cust_Sex'][test_mask])
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2338881131.py:7: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   test.loc[test_mask, 'Join_Channel'] = le.fit_transform(test['Join_Channel'][test_mask])
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2338881131.py:11: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   test.loc[test_mask, 'Cust_Segment'] = le.fit_transform(test['Cust_Segment'][test_mask])
# /var/folders/_c/mh2m7mrx5cn757_w77mtjytr0000gn/T/ipykernel_13379/2338881131.py:15: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   test.loc[test_mask, 'Cust_Province_Cd'] = le.fit_transform(test['Cust_Province_Cd'][test_mask])

# %%
#Get rid of the ages 30 and 40 - stratify

# %%
#todo - fix the test data

# %%
#map to english transaltion
